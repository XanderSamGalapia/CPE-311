# %% [markdown]
# ##**Seatwork 6.1 Exploratory Data Analysis on Your Own Dataset**
#
# CPE311 Computational Thinking with Python
#
# Name: Galapia, Xander Sam E.
#
# Section: CPE22S3
#
# Performed on: 03/11/2024
#
# Submitted on: 03/13/2024
#
# Submitted to: Engr. Roman M. Richard

# %%
filepath = '/content/chocolate.csv'
#Importing both numpy,panda
import numpy as np
import pandas as pd

# %%
choc = pd.read_csv(filepath)
choc
# Out:
#        ref company_manufacturer company_location  review_date  \
# 0     2454                 5150           U.S.A.         2019
# 1     2458                 5150           U.S.A.         2019
# 2     2454                 5150           U.S.A.         2019
# 3     2542                 5150           U.S.A.         2021
# 4     2546                 5150           U.S.A.         2021
# ...    ...                  ...              ...          ...
# 2525  1205               Zotter          Austria         2014
# 2526  1996               Zotter          Austria         2017
# 2527  2036               Zotter          Austria         2018
# 2528  2170               Zotter          Austria         2018
# 2529  2170               Zotter          Austria         2018
#
#      country_of_bean_origin specific_bean_origin_or_bar_name cocoa_percent  \
# 0                  Tanzania            Kokoa Kamili, batch 1           76%
# ...

# %%
#Printing Columns of data
choc.columns
# Out:
# Index(['ref', 'company_manufacturer', 'company_location', 'review_date',
#        'country_of_bean_origin', 'specific_bean_origin_or_bar_name',
#        'cocoa_percent', 'ingredients', 'most_memorable_characteristics',
#        'rating'],
#       dtype='object')

# %%
#Removing the ref column
choc.drop(['ref'], axis = 1 , inplace=True)
choc.drop(['ingredients'], axis = 1, inplace=True)

choc
# Out:
#      company_manufacturer company_location  review_date  \
# 0                    5150           U.S.A.         2019
# 1                    5150           U.S.A.         2019
# 2                    5150           U.S.A.         2019
# 3                    5150           U.S.A.         2021
# 4                    5150           U.S.A.         2021
# ...                   ...              ...          ...
# 2525               Zotter          Austria         2014
# 2526               Zotter          Austria         2017
# 2527               Zotter          Austria         2018
# 2528               Zotter          Austria         2018
# 2529               Zotter          Austria         2018
#
#      country_of_bean_origin specific_bean_origin_or_bar_name cocoa_percent  \
# 0                  Tanzania            Kokoa Kamili, batch 1           76%
# 1        Dominican Republic                  Zorzal, batch 1           76%
# ...

# %%
#Renaming/shorten the name of company_location to Company
choc.rename(columns = {'company_location': 'Company'}, inplace = True)
choc
# Out:
#      company_manufacturer  Company  review_date country_of_bean_origin  \
# 0                    5150   U.S.A.         2019               Tanzania
# 1                    5150   U.S.A.         2019     Dominican Republic
# 2                    5150   U.S.A.         2019             Madagascar
# 3                    5150   U.S.A.         2021                   Fiji
# 4                    5150   U.S.A.         2021              Venezuela
# ...                   ...      ...          ...                    ...
# 2525               Zotter  Austria         2014                  Blend
# 2526               Zotter  Austria         2017               Colombia
# 2527               Zotter  Austria         2018                  Blend
# 2528               Zotter  Austria         2018                  Congo
# 2529               Zotter  Austria         2018                 Belize
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Kokoa Kamili, batch 1           76%
# ...

# %%
#Renaming/shorten the name of country of bean origin
choc.rename(columns = {'country_of_bean_origin': 'Bean_Origin'}, inplace = True)
choc
# Out:
#      company_manufacturer  Company  review_date         Bean_Origin  \
# 0                    5150   U.S.A.         2019            Tanzania
# 1                    5150   U.S.A.         2019  Dominican Republic
# 2                    5150   U.S.A.         2019          Madagascar
# 3                    5150   U.S.A.         2021                Fiji
# 4                    5150   U.S.A.         2021           Venezuela
# ...                   ...      ...          ...                 ...
# 2525               Zotter  Austria         2014               Blend
# 2526               Zotter  Austria         2017            Colombia
# 2527               Zotter  Austria         2018               Blend
# 2528               Zotter  Austria         2018               Congo
# 2529               Zotter  Austria         2018              Belize
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Kokoa Kamili, batch 1           76%
# ...

# %%
##All chocolate with the rating of 1
rate2 = choc[choc['rating'] == 1].copy()
rate2
# Out:
#      company_manufacturer   Company  review_date Bean_Origin  \
# 430             Callebaut   Belgium         2007     Ecuador
# 590       Claudio Corallo  Sao Tome         2008       Blend
# 632    Cote d' Or (Kraft)   Belgium         2006       Blend
# 1679  Neuhaus (Callebaut)   Belgium         2007       Blend
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 430                            Baking           70%
# 590     Principe, Sao Tome & Principe          100%
# 632                Sensations Intense           70%
# 1679                             Dark           73%
#
#      most_memorable_characteristics  rating
# 430                   bitter, cocoa     1.0
# 590      chalky, musty, very bitter     1.0
# 632           this is not chocolate     1.0
# 1679      pastey, strong off flavor     1.0

# %%
##All chocolate ratings above 3
rate3 = choc[choc['rating'] >= 3].copy()
rate3
# Out:
#      company_manufacturer  Company  review_date         Bean_Origin  \
# 0                    5150   U.S.A.         2019            Tanzania
# 1                    5150   U.S.A.         2019  Dominican Republic
# 2                    5150   U.S.A.         2019          Madagascar
# 3                    5150   U.S.A.         2021                Fiji
# 4                    5150   U.S.A.         2021           Venezuela
# ...                   ...      ...          ...                 ...
# 2524               Zotter  Austria         2012  Dominican Republic
# 2526               Zotter  Austria         2017            Colombia
# 2527               Zotter  Austria         2018               Blend
# 2528               Zotter  Austria         2018               Congo
# 2529               Zotter  Austria         2018              Belize
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Kokoa Kamili, batch 1           76%
# ...

# %%
##All chocolate ratings with 4 and above rating
best = choc[choc['rating'] >= 4].copy()
best
# Out:
#      company_manufacturer Company  review_date Bean_Origin  \
# 18               A. Morin  France         2013   Venezuela
# 19               A. Morin  France         2013        Peru
# 24               A. Morin  France         2014        Peru
# 32               A. Morin  France         2021      Mexico
# 79                  Amano  U.S.A.         2010     Ecuador
# ...                   ...     ...          ...         ...
# 2394             Valrhona  France         2011   Venezuela
# 2395             Valrhona  France         2012   Venezuela
# 2398             Valrhona  France         2015        Peru
# 2459       Willie's Cacao    U.K.         2016    Colombia
# 2467            Woodblock  U.S.A.         2011   Venezuela
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 18                              Chuao           70%
# 19               Chanchamayo Province           63%
# 24                            Pablino           70%
# ...

# %%
#All chocolates under U.S.A. Company
USA = choc[choc['Company'] == 'U.S.A.'].copy()
USA
# Out:
#      company_manufacturer Company  review_date         Bean_Origin  \
# 0                    5150  U.S.A.         2019            Tanzania
# 1                    5150  U.S.A.         2019  Dominican Republic
# 2                    5150  U.S.A.         2019          Madagascar
# 3                    5150  U.S.A.         2021                Fiji
# 4                    5150  U.S.A.         2021           Venezuela
# ...                   ...     ...          ...                 ...
# 2489                Zak's  U.S.A.         2015               Blend
# 2490                Zak's  U.S.A.         2015  Dominican Republic
# 2491                Zak's  U.S.A.         2015          Madagascar
# 2492                Zak's  U.S.A.         2015                Peru
# 2493                Zak's  U.S.A.         2015              Belize
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Kokoa Kamili, batch 1           76%
# 1                     Zorzal, batch 1           76%
# ...

# %%
#All rating of less than or equal to 3
us4 = USA[USA['rating'] <= 3].copy()
us4
# Out:
#        company_manufacturer Company  review_date         Bean_Origin  \
# 3                      5150  U.S.A.         2021                Fiji
# 4                      5150  U.S.A.         2021           Venezuela
# 61    Altus aka Cao Artisan  U.S.A.         2013           Venezuela
# 62    Altus aka Cao Artisan  U.S.A.         2013  Dominican Republic
# 63    Altus aka Cao Artisan  U.S.A.         2013             Bolivia
# ...                     ...     ...          ...                 ...
# 2482                Xocolla  U.S.A.         2017  Dominican Republic
# 2483                Xocolla  U.S.A.         2017          Madagascar
# 2487              Zacharias  U.S.A.         2021             Bolivia
# 2488                  Zak's  U.S.A.         2015    Papua New Guinea
# 2489                  Zak's  U.S.A.         2015               Blend
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 3               Matasawalevu, batch 1           68%
# ...

# %%
#Mean, Median, Standard Deviation, Max, Min of the chocolate ratings in USA
usmean = np.mean(USA['rating']).copy()
usmed = np.median(USA['rating']).copy()
ustd = np.std(USA['rating']).copy()
usmin = np.min(USA['rating']).copy()
usmax = np.max(USA['rating']).copy()


print("The mean for the chocolate rating in USA is: ",usmean)
print("The median for the chocolate rating in USA is: ",usmed)
print("The Standard Deviation for the chocolate rating in USA is: ",ustd)
print("The Minimum for the chocolate rating in USA is: ",usmin)
print("The Maximum for the chocolate rating in USA is: ",usmax)
# Out:
# The mean for the chocolate rating in USA is:  3.190801056338028
# The median for the chocolate rating in USA is:  3.25
# The Standard Deviation for the chocolate rating in USA is:  0.42410984974033733
# The Minimum for the chocolate rating in USA is:  1.5
# The Maximum for the chocolate rating in USA is:  4.0

# %%
#Printing all Japan chocolate listed in the data
JP = choc[choc['Company'] == 'Japan'].copy()
JP
# Out:
#              company_manufacturer Company  review_date       Bean_Origin  \
# 416                   Cacao Store   Japan         2015        Madagascar
# 417                   Cacao Store   Japan         2015              Peru
# 418                   Cacao Store   Japan         2015           Vietnam
# 551                     ChocoReko   Japan         2015         Venezuela
# 846                       Emily's   Japan         2015         Venezuela
# 847                       Emily's   Japan         2015              Peru
# 1072            Green Bean to Bar   Japan         2016        Madagascar
# 1073            Green Bean to Bar   Japan         2019              Peru
# 1319      La Chocolaterie Nanairo   Japan         2016              Peru
# 1320      La Chocolaterie Nanairo   Japan         2016              Peru
# 1321      La Chocolaterie Nanairo   Japan         2016            Belize
# 1322      La Chocolaterie Nanairo   Japan         2016              Peru
# ...

# %%
#Mean, Median, STD, Min, and Max rating for Japan's Chocolate
jpmean = np.mean(JP['rating']).copy()
jpmed = np.median(JP['rating']).copy()
jpstd = np.std(JP['rating']).copy()
jpmin = np.min(JP['rating']).copy()
jpmax = np.max(JP['rating']).copy()

print("The mean for the chocolate rating in Japan is: ",jpmean)
print("The median for the chocolate rating in Japan is: ",jpmed)
print("Standard Deviation rating: ",jpstd)
print("Minimum Rate of Chocolate in Japan: ", jpmin)
print("Maximum Rate of Chocolate in Japan: ", jpmax)
# Out:
# The mean for the chocolate rating in Japan is:  3.129032258064516
# The median for the chocolate rating in Japan is:  3.25
# Standard Deviation rating:  0.3695625560448258
# Minimum Rate of Chocolate in Japan:  2.25
# Maximum Rate of Chocolate in Japan:  3.75

# %%
#All 2015 onwards review_date
y2015 = choc[choc['review_date'] >= 2015].copy()
y2015
# Out:
#      company_manufacturer  Company  review_date         Bean_Origin  \
# 0                    5150   U.S.A.         2019            Tanzania
# 1                    5150   U.S.A.         2019  Dominican Republic
# 2                    5150   U.S.A.         2019          Madagascar
# 3                    5150   U.S.A.         2021                Fiji
# 4                    5150   U.S.A.         2021           Venezuela
# ...                   ...      ...          ...                 ...
# 2508    Zoto (Chocolatoa)  Belgium         2018           Nicaragua
# 2526               Zotter  Austria         2017            Colombia
# 2527               Zotter  Austria         2018               Blend
# 2528               Zotter  Austria         2018               Congo
# 2529               Zotter  Austria         2018              Belize
#
#           specific_bean_origin_or_bar_name cocoa_percent  \
# 0                    Kokoa Kamili, batch 1           76%
# ...

# %%
#All 2018 year for the y2015 onwards data
y18 = y2015[y2015['review_date'] == 2018].copy()
y18
# Out:
#        company_manufacturer  Company  review_date         Bean_Origin  \
# 30                 A. Morin   France         2018           Venezuela
# 31                 A. Morin   France         2018                Peru
# 71    Altus aka Cao Artisan   U.S.A.         2018  Dominican Republic
# 103                  Amedei    Italy         2018          Madagascar
# 104                  Amedei    Italy         2018           Venezuela
# ...                     ...      ...          ...                 ...
# 2507      Zoto (Chocolatoa)  Belgium         2018           Nicaragua
# 2508      Zoto (Chocolatoa)  Belgium         2018           Nicaragua
# 2527                 Zotter  Austria         2018               Blend
# 2528                 Zotter  Austria         2018               Congo
# 2529                 Zotter  Austria         2018              Belize
#
#           specific_bean_origin_or_bar_name cocoa_percent  \
# 30                               Porcelana           70%
# ...

# %%
choc['category'] = np.where(choc['rating'] >= 4, 'Good', 'Average')
choc
# Out:
#      company_manufacturer  Company  review_date         Bean_Origin  \
# 0                    5150   U.S.A.         2019            Tanzania
# 1                    5150   U.S.A.         2019  Dominican Republic
# 2                    5150   U.S.A.         2019          Madagascar
# 3                    5150   U.S.A.         2021                Fiji
# 4                    5150   U.S.A.         2021           Venezuela
# ...                   ...      ...          ...                 ...
# 2525               Zotter  Austria         2014               Blend
# 2526               Zotter  Austria         2017            Colombia
# 2527               Zotter  Austria         2018               Blend
# 2528               Zotter  Austria         2018               Congo
# 2529               Zotter  Austria         2018              Belize
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Kokoa Kamili, batch 1           76%
# ...

# %%
choc['category'] = np.where(choc['rating'] <= 2, 'Substandard', 'Average')
choc
# Out:
#      company_manufacturer  Company  review_date         Bean_Origin  \
# 0                    5150   U.S.A.         2019            Tanzania
# 1                    5150   U.S.A.         2019  Dominican Republic
# 2                    5150   U.S.A.         2019          Madagascar
# 3                    5150   U.S.A.         2021                Fiji
# 4                    5150   U.S.A.         2021           Venezuela
# ...                   ...      ...          ...                 ...
# 2525               Zotter  Austria         2014               Blend
# 2526               Zotter  Austria         2017            Colombia
# 2527               Zotter  Austria         2018               Blend
# 2528               Zotter  Austria         2018               Congo
# 2529               Zotter  Austria         2018              Belize
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Kokoa Kamili, batch 1           76%
# ...

# %%
Gd = choc[choc['category'] == 'Good'].copy()
Gd
# Out:
#      company_manufacturer Company  review_date Bean_Origin  \
# 18               A. Morin  France         2013   Venezuela
# 19               A. Morin  France         2013        Peru
# 24               A. Morin  France         2014        Peru
# 32               A. Morin  France         2021      Mexico
# 79                  Amano  U.S.A.         2010     Ecuador
# ...                   ...     ...          ...         ...
# 2394             Valrhona  France         2011   Venezuela
# 2395             Valrhona  France         2012   Venezuela
# 2398             Valrhona  France         2015        Peru
# 2459       Willie's Cacao    U.K.         2016    Colombia
# 2467            Woodblock  U.S.A.         2011   Venezuela
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 18                              Chuao           70%
# 19               Chanchamayo Province           63%
# 24                            Pablino           70%
# ...

# %%
av = choc[choc['category'] == 'Average'].copy()
av
# Out:
#      company_manufacturer  Company  review_date         Bean_Origin  \
# 0                    5150   U.S.A.         2019            Tanzania
# 1                    5150   U.S.A.         2019  Dominican Republic
# 2                    5150   U.S.A.         2019          Madagascar
# 3                    5150   U.S.A.         2021                Fiji
# 4                    5150   U.S.A.         2021           Venezuela
# ...                   ...      ...          ...                 ...
# 2525               Zotter  Austria         2014               Blend
# 2526               Zotter  Austria         2017            Colombia
# 2527               Zotter  Austria         2018               Blend
# 2528               Zotter  Austria         2018               Congo
# 2529               Zotter  Austria         2018              Belize
#
#      specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Kokoa Kamili, batch 1           76%
# ...

# %%
ss = choc[choc['category'] == 'Substandard'].copy()
ss
# Out:
#                 company_manufacturer      Company  review_date  \
# 158              Artisan du Chocolat         U.K.         2009
# 164              Artisan du Chocolat         U.K.         2010
# 293                           Bonnat       France         2006
# 323           Bouga Cacao (Tulicorp)      Ecuador         2009
# 373                      Cacao Barry       France         2007
# 375                      Cacao Barry       France         2008
# 426          Cacaoyere (Ecuatoriana)      Ecuador         2008
# 430                        Callebaut      Belgium         2007
# 448                 Caoni (Tulicorp)      Ecuador         2008
# 470                             Casa       U.S.A.         2018
# 590                  Claudio Corallo     Sao Tome         2008
# 626                        Coppeneur      Germany         2012
# 632               Cote d' Or (Kraft)      Belgium         2006
# 763               Dolfin (Belcolade)      Belgium         2006
# ...

# %%
allmean = np.mean(choc['rating'])
allmed = np.median(choc['rating'])
allstd = np.std(choc['rating'])
allmin = np.min(choc['rating'])
allmax = np.max(choc['rating'])
print("Mean of all choco:" , allmean)
print("Median of all choco: ", allmed)
print("Standard Deviation of all choco: ", allstd)
print("Lowest Rating: ", allmin)
print("Highest Rating: ", allmax)
# Out:
# Mean of all choco: 3.1963438735177867
# Median of all choco:  3.25
# Standard Deviation of all choco:  0.4452332873561636
# Lowest Rating:  1.0
# Highest Rating:  4.0

# %%
choc.describe()
# Out:
#        review_date       rating
# count  2530.000000  2530.000000
# mean   2014.374308     3.196344
# std       3.968267     0.445321
# min    2006.000000     1.000000
# 25%    2012.000000     3.000000
# 50%    2015.000000     3.250000
# 75%    2018.000000     3.500000
# max    2021.000000     4.000000

# %% [markdown]
# Google Colab Link: [link text](https://colab.research.google.com/drive/1QIpbdPR0YEXKwaW-le9XTYzSR3nuXcnV?usp=sharing)
